# %%
pip install --upgrade diffusers transformers scipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 57.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 43.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.16.1
#     Uninstalling transformers-5.16.1:
#       Successfully uninstalled transformers-5.16.1
# ...

# %%
import torch

print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# 2.11.0+cu128
# True
# Tesla T4

# %%
import torch
from diffusers import StableDiffusionPipeline

model_id = "CompVis/stable-diffusion-v1-4"

pipe = StableDiffusionPipeline.from_pretrained(
    model_id,
    dtype=torch.float16
)

pipe = pipe.to("cuda")

prompt = "Man in a suit with a fish head, paper vintage texture"

image = pipe(prompt).images[0]

image.save("surreal_collage_1.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
import torch
from diffusers import StableDiffusionPipeline

model_id = "CompVis/stable-diffusion-v1-4"

pipe = StableDiffusionPipeline.from_pretrained(
    model_id,
    dtype=torch.float16
)

pipe = pipe.to("cuda")

prompt = "paper drawn man in a suit with a large black rotary telephone head. Paper vintage texture."

image = pipe(prompt).images[0]

image.save("surreal_collage_2.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
import torch
from diffusers import StableDiffusionPipeline

model_id = "CompVis/stable-diffusion-v1-4"

pipe = StableDiffusionPipeline.from_pretrained(
    model_id,
    dtype=torch.float16
)

pipe = pipe.to("cuda")

prompt = "Man in a light blue suit with a large antique clock head. Green background. Paper vintage texture."

image = pipe(prompt).images[0]

image.save("surreal_collage_3.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
